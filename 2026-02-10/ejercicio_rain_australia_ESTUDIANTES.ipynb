# %% [markdown]
# # 🌧️ Predicción de Lluvia en Australia con Redes Neuronales
# ## **EJERCICIO PRÁCTICO - VERSIÓN PARA ALUMNOS**
#
# ---
#
# ## 🎯 Objetivo del Ejercicio
#
# Desarrollar una red neuronal que prediga si **lloverá mañana** basándose en datos meteorológicos actuales de diferentes ciudades australianas.
#
# ---
#
# ## 📊 Información del Dataset
#
# **Rain in Australia Dataset:**
# - **Fuente**: Observaciones meteorológicas diarias de estaciones australianas (10 años)
# - **Muestras**: ~145,460 observaciones
# - **Features**: 23 características meteorológicas
# - **Target**: `RainTomorrow` (Sí/No - ¿lloverá mañana?)
# - **URL**: https://raw.githubusercontent.com/jbrownlee/Datasets/master/weatherAUS.csv
#
# ### 🌡️ Variables Principales:
# - **Ubicación**: Ciudad/estación meteorológica
# - **Temperatura**: Min, Max, 9am, 3pm
# - **Humedad**: 9am, 3pm
# - **Presión**: 9am, 3pm
# - **Viento**: Velocidad y dirección (9am, 3pm)
# - **Nubosidad**: 9am, 3pm
# - **Lluvia**: Cantidad hoy, si llovió hoy
#
# ---
#
# ## 📝 Instrucciones Generales
#
# 1. ✅ **Lee atentamente** cada instrucción antes de escribir código
# 2. ✅ **Completa el código** en las celdas marcadas con `# TU CÓDIGO AQUÍ`
# 3. ✅ **Ejecuta las celdas** en orden secuencial
# 4. ✅ **Verifica los resultados** después de cada paso
# 5. ✅ **Consulta la documentación** si tienes dudas
#
# ---

# %% [markdown]
# ## 1️⃣ Instalación de Librerías
#
# ### 📝 Tarea:
# Instala las siguientes librerías necesarias para el proyecto:
# - `tensorflow` (redes neuronales)
# - `pandas` (manipulación de datos)
# - `numpy` (operaciones numéricas)
# - `matplotlib` (visualización)
# - `seaborn` (visualización avanzada)
# - `scikit-learn` (preprocesamiento y métricas)
#
# ### 💡 Pista:
# Usa `%pip install` seguido de los nombres de las librerías separados por espacios.

# %%
# TU CÓDIGO AQUÍ: Instala las librerías necesarias
# %pip install pandas matploitlib seaborn scikit-learn tensorflow

# %% [markdown]
# ## 2️⃣ Importación de Librerías
#
# ### 📝 Tarea:
# Importa todas las librerías necesarias para el proyecto.
#
# ### 💡 Pistas:
# - Importa `pandas` como `pd`
# - Importa `numpy` como `np`
# - Importa `matplotlib.pyplot` como `plt`
# - Importa `seaborn` como `sns`
# - Importa `tensorflow` como `tf`
# - De `tensorflow.keras`, importa `layers` y `models`
# - De `sklearn.model_selection`, importa `train_test_split`
# - De `sklearn.preprocessing`, importa `StandardScaler` y `LabelEncoder`
# - De `sklearn.metrics`, importa: `confusion_matrix`, `classification_report`, `roc_auc_score`, `roc_curve`, `accuracy_score`, `precision_score`, `recall_score`, `f1_score`
#
# ### 🔧 Configuración adicional:
# - Establece la semilla aleatoria en 42 para `numpy` y `tensorflow`
# - Configura `warnings.filterwarnings('ignore')`

# %%
# TU CÓDIGO AQUÍ: Importa todas las librerías necesarias







# Configura las semillas aleatorias y warnings



# Imprime las versiones de TensorFlow y Pandas
print(f"✅ TensorFlow versión: {tf.__version__}")
print(f"✅ Pandas versión: {pd.__version__}")

# %% [markdown]
# ## 3️⃣ Carga del Dataset
#
# ### 📝 Tarea:
# Carga el dataset desde la URL proporcionada usando pandas.
#
# ### 💡 Pistas:
# - URL: `'https://raw.githubusercontent.com/jbrownlee/Datasets/master/weatherAUS.csv'`
# - Usa `pd.read_csv()` para cargar el archivo
# - Almacena el resultado en una variable llamada `df`
# - Muestra la forma del dataset (shape) y las primeras filas
#
# ### ❓ Preguntas para reflexionar:
# - ¿Cuántas filas y columnas tiene el dataset?
# - ¿Qué tipo de datos contiene?

# %%
# TU CÓDIGO AQUÍ: Carga el dataset desde la URL
url = 'weatherAUS.csv'

# Carga el dataset


# Muestra información básica
print(f"✅ Dataset cargado exitosamente")
print(f"📊 Forma del dataset: {df.shape}")

# %% [markdown]
# ## 4️⃣ Exploración Inicial de Datos (EDA)
#
# ### 4.1 Primeras Filas del Dataset
#
# ### 📝 Tarea:
# Muestra las primeras 5 filas del dataset para familiarizarte con los datos.

# %%
# TU CÓDIGO AQUÍ: Muestra las primeras 5 filas
print("🔍 Primeras 5 filas del dataset:\n")

# %% [markdown]
# ### 4.2 Información General del Dataset
#
# ### 📝 Tarea:
# Usa el método `.info()` para ver información sobre las columnas, tipos de datos y valores no nulos.

# %%
# TU CÓDIGO AQUÍ: Muestra información del dataset
print("📋 Información del dataset:\n")

# %% [markdown]
# ### 4.3 Estadísticas Descriptivas
#
# ### 📝 Tarea:
# Genera estadísticas descriptivas de las columnas numéricas.

# %%
# TU CÓDIGO AQUÍ: Muestra estadísticas descriptivas
print("📊 Estadísticas descriptivas:\n")

# %% [markdown]
# ### 4.4 Análisis de la Variable Objetivo
#
# ### 📝 Tarea:
# Analiza la distribución de la variable objetivo `RainTomorrow`.
#
# ### 💡 Pistas:
# - Usa `.value_counts()` para contar las ocurrencias
# - Calcula los porcentajes con `.value_counts(normalize=True) * 100`
# - Crea visualizaciones (gráfico de barras y gráfico de pastel)
#
# ### ❓ Preguntas:
# - ¿Están las clases balanceadas?
# - ¿Cuál es el ratio entre "No" y "Yes"?
# - ¿Esto podría afectar al modelo?

# %%
# TU CÓDIGO AQUÍ: Analiza la distribución de RainTomorrow
print("🎯 Distribución de la variable objetivo (RainTomorrow):\n")

# Cuenta de valores


# Porcentajes


# Visualización (gráfico de barras y pastel)
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

# Gráfico de barras en axes[0]
# TU CÓDIGO AQUÍ


# Gráfico de pastel en axes[1]
# TU CÓDIGO AQUÍ


plt.tight_layout()
plt.show()

# %% [markdown]
# ### 4.5 Análisis de Valores Faltantes
#
# ### 📝 Tarea:
# Identifica y visualiza los valores faltantes en el dataset.
#
# ### 💡 Pistas:
# - Usa `.isnull().sum()` para contar valores nulos por columna
# - Calcula el porcentaje de valores faltantes
# - Crea un gráfico de barras horizontales para visualizar
#
# ### ❓ Preguntas:
# - ¿Qué columnas tienen más valores faltantes?
# - ¿Hay alguna columna con más del 40% de valores faltantes?
# - ¿Deberías eliminar alguna columna?

# %%
# TU CÓDIGO AQUÍ: Analiza valores faltantes

# Cuenta de valores faltantes


# Crea un DataFrame con columna, valores faltantes y porcentaje



# Ordena por valores faltantes descendente


# Muestra solo las columnas con valores faltantes
print("❌ Valores faltantes por columna:\n")


# Visualización (gráfico de barras horizontal)
# TU CÓDIGO AQUÍ

# %% [markdown]
# ## 5️⃣ Preprocesamiento de Datos
#
# ### 5.1 Eliminar Columnas Innecesarias
#
# ### 📝 Tarea:
# Elimina la columna `Date` ya que no aporta información predictiva directa.
#
# ### 💡 Pista:
# Usa `.drop()` con `axis=1` para eliminar columnas.

# %%
# TU CÓDIGO AQUÍ: Elimina la columna Date
print("🗑️ Eliminando columna 'Date'...")


print(f"✅ Nueva forma del dataset: {df_clean.shape}")

# %% [markdown]
# ### 5.2 Eliminar Filas con Target Faltante
#
# ### 📝 Tarea:
# Elimina las filas donde `RainTomorrow` es NaN (no podemos entrenar sin la variable objetivo).
#
# ### 💡 Pista:
# Usa `.dropna()` con el parámetro `subset=['RainTomorrow']`

# %%
# TU CÓDIGO AQUÍ: Elimina filas con RainTomorrow faltante
print(f"📊 Filas antes: {len(df_clean):,}")


print(f"📊 Filas después: {len(df_clean):,}")

# %% [markdown]
# ### 5.3 Separar Features y Target
#
# ### 📝 Tarea:
# Separa el dataset en:
# - `X`: Features (todas las columnas excepto `RainTomorrow`)
# - `y`: Target (solo la columna `RainTomorrow`)
#
# ### 💡 Pista:
# Usa `.drop()` para X y selección directa para y.

# %%
# TU CÓDIGO AQUÍ: Separa X e y



print(f"✅ X shape: {X.shape}")
print(f"✅ y shape: {y.shape}")

# %% [markdown]
# ### 5.4 Identificar Columnas Numéricas y Categóricas
#
# ### 📝 Tarea:
# Identifica qué columnas son numéricas y cuáles categóricas.
#
# ### 💡 Pistas:
# - Usa `.select_dtypes(include=['int64', 'float64'])` para numéricas
# - Usa `.select_dtypes(include=['object'])` para categóricas
# - Obtén los nombres de las columnas con `.columns.tolist()`

# %%
# TU CÓDIGO AQUÍ: Identifica columnas numéricas y categóricas



print(f"🔢 Features numéricas ({len(numeric_features)}):")
print(numeric_features)
print(f"\n📝 Features categóricas ({len(categorical_features)}):")
print(categorical_features)

# %% [markdown]
# ### 5.5 Imputación de Valores Faltantes
#
# ### 📝 Tarea:
# Rellena los valores faltantes usando:
# - **Mediana** para variables numéricas (más robusta a outliers que la media)
# - **Moda** para variables categóricas (valor más frecuente)
#
# ### 💡 Pistas:
# - Usa `.median()` para calcular la mediana
# - Usa `.mode()[0]` para calcular la moda
# - Usa `.fillna()` con `inplace=True` para rellenar
# - Itera sobre `numeric_features` y `categorical_features`

# %%
# TU CÓDIGO AQUÍ: Imputa valores faltantes en numéricas
print("🔧 Imputando valores faltantes en features numéricas...")
for col in numeric_features:
    if X[col].isnull().sum() > 0:
        # Calcula la mediana y rellena los valores faltantes
        # TU CÓDIGO AQUÍ
        
        print(f"   ✓ {col}: rellenados con mediana")

# TU CÓDIGO AQUÍ: Imputa valores faltantes en categóricas
print("\n🔧 Imputando valores faltantes en features categóricas...")
for col in categorical_features:
    if X[col].isnull().sum() > 0:
        # Calcula la moda y rellena los valores faltantes
        # TU CÓDIGO AQUÍ
        
        print(f"   ✓ {col}: rellenados con moda")

# Verifica que no quedan valores faltantes
print(f"\n✅ Total de valores faltantes restantes: {X.isnull().sum().sum()}")

# %% [markdown]
# ### 5.6 Encoding de Variables Categóricas
#
# ### 📝 Tarea:
# Convierte las variables categóricas a numéricas:
# - **Label Encoding** para `RainToday` (variable binaria Yes/No)
# - **One-Hot Encoding** para variables con múltiples categorías (`Location`, `WindGustDir`, `WindDir9am`, `WindDir3pm`)
#
# ### 💡 Pistas:
# - Usa `LabelEncoder()` de sklearn para Label Encoding
# - Usa `pd.get_dummies()` para One-Hot Encoding
# - Recuerda usar `drop_first=True` en get_dummies para evitar multicolinealidad
#
# ### ❓ Pregunta:
# - ¿Por qué usamos Label Encoding para RainToday y One-Hot para Location?

# %%
# TU CÓDIGO AQUÍ: Label Encoding para variables binarias
print("🔤 Aplicando Label Encoding a variables binarias...")

binary_features = ['RainToday']

# Crea un LabelEncoder


# Aplica Label Encoding a RainToday



# TU CÓDIGO AQUÍ: One-Hot Encoding para variables categóricas
print("\n🔤 Aplicando One-Hot Encoding a variables categóricas...")

multi_categorical = ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm']

# Aplica One-Hot Encoding


print(f"\n✅ Shape después de encoding: {X_encoded.shape}")
print(f"📊 Nuevas features creadas: {X_encoded.shape[1] - X.shape[1]}")

# %% [markdown]
# ### 5.7 Encoding de la Variable Objetivo
#
# ### 📝 Tarea:
# Convierte `RainTomorrow` de 'Yes'/'No' a 1/0.
#
# ### 💡 Pista:
# Usa `(y == 'Yes').astype(int)` para convertir.

# %%
# TU CÓDIGO AQUÍ: Codifica y como 0/1


print("🎯 Variable objetivo codificada:")
print(f"   No (0): {(y_encoded == 0).sum():,}")
print(f"   Sí (1): {(y_encoded == 1).sum():,}")

# %% [markdown]
# ### 5.8 División Train/Test
#
# ### 📝 Tarea:
# Divide el dataset en conjuntos de entrenamiento (80%) y prueba (20%).
#
# ### 💡 Pistas:
# - Usa `train_test_split()` de sklearn
# - Parámetros: `test_size=0.2`, `random_state=42`, `stratify=y_encoded`
# - Stratify mantiene la proporción de clases en ambos conjuntos
#
# ### ❓ Pregunta:
# - ¿Por qué es importante usar `stratify` cuando las clases están desbalanceadas?

# %%
# TU CÓDIGO AQUÍ: Divide en train y test



print("📂 División de datos:")
print(f"   X_train: {X_train.shape}")
print(f"   X_test:  {X_test.shape}")
print(f"   y_train: {y_train.shape}")
print(f"   y_test:  {y_test.shape}")

# %% [markdown]
# ### 5.9 Normalización de Features
#
# ### 📝 Tarea:
# Normaliza las features para que tengan media 0 y desviación estándar 1.
#
# ### 💡 Pistas:
# - Usa `StandardScaler()` de sklearn
# - Primero haz `.fit_transform()` en X_train
# - Luego solo `.transform()` en X_test (NO hagas fit en test)
#
# ### ❓ Pregunta:
# - ¿Por qué NO debemos hacer fit en el conjunto de test?

# %%
# TU CÓDIGO AQUÍ: Normaliza las features
print("⚙️ Normalizando features...")

# Crea el scaler


# Fit y transforma el train


# Solo transforma el test


print(f"✅ Features normalizadas")
print(f"   Media de X_train: {X_train_scaled.mean():.6f}")
print(f"   Std de X_train: {X_train_scaled.std():.6f}")

# %% [markdown]
# ## 6️⃣ Construcción del Modelo de Red Neuronal
#
# ### 📝 Tarea:
# Construye una red neuronal con la siguiente arquitectura:
#
# ```
# Entrada → Dense(128, ReLU) → Dropout(0.3)
#        → Dense(64, ReLU)  → Dropout(0.3)
#        → Dense(32, ReLU)  → Dropout(0.2)
#        → Dense(1, Sigmoid)
# ```
#
# ### 💡 Pistas:
# - Usa `models.Sequential()`
# - Primera capa: `layers.Input(shape=(X_train_scaled.shape[1],))`
# - Capas densas: `layers.Dense(neuronas, activation='relu')`
# - Dropout: `layers.Dropout(tasa)`
# - Última capa: `layers.Dense(1, activation='sigmoid')` (para clasificación binaria)
#
# ### ❓ Preguntas:
# - ¿Por qué usamos ReLU en las capas ocultas?
# - ¿Por qué usamos Sigmoid en la salida?
# - ¿Para qué sirve el Dropout?

# %%
# TU CÓDIGO AQUÍ: Construye el modelo

model = models.Sequential([
    # Capa de entrada
    # TU CÓDIGO AQUÍ
    
    # Primera capa oculta (128 neuronas, ReLU) + Dropout 0.3
    # TU CÓDIGO AQUÍ
    
    
    # Segunda capa oculta (64 neuronas, ReLU) + Dropout 0.3
    # TU CÓDIGO AQUÍ
    
    
    # Tercera capa oculta (32 neuronas, ReLU) + Dropout 0.2
    # TU CÓDIGO AQUÍ
    
    
    # Capa de salida (1 neurona, Sigmoid)
    # TU CÓDIGO AQUÍ
    
])

# Muestra la arquitectura
print("🏗️ Arquitectura del modelo:\n")
model.summary()

# %% [markdown]
# ## 7️⃣ Compilación del Modelo
#
# ### 📝 Tarea:
# Compila el modelo configurando:
# - **Optimizador**: Adam
# - **Función de pérdida**: Binary Crossentropy
# - **Métricas**: accuracy, precision, recall, AUC
#
# ### 💡 Pistas:
# - Usa `model.compile()`
# - Para métricas adicionales usa: `tf.keras.metrics.Precision()`, `Recall()`, `AUC()`
#
# ### ❓ Pregunta:
# - ¿Por qué usamos Binary Crossentropy y no Categorical Crossentropy?

# %%
# TU CÓDIGO AQUÍ: Compila el modelo








print("✅ Modelo compilado correctamente")

# %% [markdown]
# ## 8️⃣ Cálculo de Class Weights
#
# ### 📝 Tarea:
# Calcula los pesos de clase para manejar el desbalanceo.
#
# ### 💡 Pistas:
# - Usa `compute_class_weight('balanced', classes=np.unique(y_train), y=y_train)` de sklearn
# - Convierte el resultado a un diccionario con `dict(enumerate(...))`
#
# ### ❓ Pregunta:
# - ¿Por qué necesitamos class weights cuando las clases están desbalanceadas?

# %%
# TU CÓDIGO AQUÍ: Calcula class weights
from sklearn.utils.class_weight import compute_class_weight




print("⚖️ Pesos de clase:")
print(f"   Clase 0 (No lluvia): {class_weights[0]:.2f}")
print(f"   Clase 1 (Sí lluvia): {class_weights[1]:.2f}")

# %% [markdown]
# ## 9️⃣ Entrenamiento del Modelo
#
# ### 📝 Tarea:
# Entrena el modelo con los siguientes parámetros:
# - **epochs**: 20
# - **batch_size**: 256
# - **validation_split**: 0.15 (15% para validación)
# - **class_weight**: usa el diccionario calculado
#
# ### 💡 Pistas:
# - Usa `model.fit()`
# - Guarda el resultado en una variable llamada `history`
# - Usa `verbose=1` para ver el progreso
#
# ### ❓ Preguntas:
# - ¿Qué significa un epoch?
# - ¿Para qué sirve el validation_split?
# - ¿Qué es el batch_size?

# %%
# TU CÓDIGO AQUÍ: Entrena el modelo
print("🚀 Iniciando entrenamiento...\n")







print("\n✅ Entrenamiento completado")

# %% [markdown]
# ## 🔟 Visualización del Entrenamiento
#
# ### 📝 Tarea:
# Crea 4 gráficos para visualizar:
# 1. Pérdida (loss) de entrenamiento vs validación
# 2. Accuracy de entrenamiento vs validación
# 3. Precision de entrenamiento vs validación
# 4. Recall de entrenamiento vs validación
#
# ### 💡 Pistas:
# - Usa `history.history['metrica']` para acceder a los valores
# - Usa `plt.subplots(2, 2, figsize=(15, 10))` para crear 4 subplots
# - Grafica con `axes[i, j].plot()`
#
# ### ❓ Preguntas:
# - ¿Hay signos de overfitting?
# - ¿Las métricas de validación mejoran con los epochs?

# %%
# TU CÓDIGO AQUÍ: Visualiza las métricas del entrenamiento

fig, axes = plt.subplots(2, 2, figsize=(15, 10))

# Gráfico de Loss en axes[0, 0]
# TU CÓDIGO AQUÍ




# Gráfico de Accuracy en axes[0, 1]
# TU CÓDIGO AQUÍ




# Gráfico de Precision en axes[1, 0]
# TU CÓDIGO AQUÍ




# Gráfico de Recall en axes[1, 1]
# TU CÓDIGO AQUÍ




plt.tight_layout()
plt.show()

# %% [markdown]
# ## 1️⃣1️⃣ Evaluación del Modelo
#
# ### 📝 Tarea:
# Evalúa el modelo en el conjunto de prueba.
#
# ### 💡 Pista:
# - Usa `model.evaluate()` con X_test_scaled e y_test

# %%
# TU CÓDIGO AQUÍ: Evalúa el modelo en test
print("📊 Evaluando modelo en conjunto de prueba...\n")



print("🎯 RESULTADOS EN EL CONJUNTO DE PRUEBA:")
print(f"   Loss:      {test_results[0]:.4f}")
print(f"   Accuracy:  {test_results[1]:.4f} ({test_results[1]*100:.2f}%)")
print(f"   Precision: {test_results[2]:.4f}")
print(f"   Recall:    {test_results[3]:.4f}")
print(f"   AUC:       {test_results[4]:.4f}")

# %% [markdown]
# ## 1️⃣2️⃣ Predicciones y Matriz de Confusión
#
# ### 📝 Tarea:
# 1. Obtén las predicciones del modelo
# 2. Convierte las probabilidades a clases (0/1) usando umbral 0.5
# 3. Calcula y visualiza la matriz de confusión
#
# ### 💡 Pistas:
# - Usa `model.predict()` para obtener probabilidades
# - Convierte a clases: `(y_pred_proba > 0.5).astype(int).flatten()`
# - Usa `confusion_matrix(y_test, y_pred)` de sklearn
# - Visualiza con `sns.heatmap()`
#
# ### ❓ Preguntas:
# - ¿Qué son los Verdaderos Positivos, Falsos Positivos, Verdaderos Negativos y Falsos Negativos?
# - ¿En qué se equivoca más el modelo?

# %%
# TU CÓDIGO AQUÍ: Obtén predicciones



# TU CÓDIGO AQUÍ: Calcula la matriz de confusión


# TU CÓDIGO AQUÍ: Visualiza la matriz de confusión
plt.figure(figsize=(8, 6))





plt.tight_layout()
plt.show()

# Interpretación
tn, fp, fn, tp = cm.ravel()
print("\n🔍 INTERPRETACIÓN DE LA MATRIZ:")
print(f"   ✅ Verdaderos Negativos (TN): {tn:,}")
print(f"   ❌ Falsos Positivos (FP):     {fp:,}")
print(f"   ❌ Falsos Negativos (FN):     {fn:,}")
print(f"   ✅ Verdaderos Positivos (TP): {tp:,}")

# %% [markdown]
# ## 1️⃣3️⃣ Curva ROC
#
# ### 📝 Tarea:
# Calcula y visualiza la curva ROC con el AUC.
#
# ### 💡 Pistas:
# - Usa `roc_curve(y_test, y_pred_proba)` para calcular FPR y TPR
# - Usa `roc_auc_score(y_test, y_pred_proba)` para el AUC
# - Grafica FPR vs TPR
# - Añade una línea diagonal de referencia (clasificador aleatorio)
#
# ### ❓ Preguntas:
# - ¿Qué significa el AUC?
# - ¿Un AUC de 0.85 es bueno?
# - ¿Qué representan FPR y TPR?

# %%
# TU CÓDIGO AQUÍ: Calcula la curva ROC



# TU CÓDIGO AQUÍ: Visualiza la curva ROC
plt.figure(figsize=(8, 6))

# Curva ROC


# Línea de referencia (clasificador aleatorio)






plt.tight_layout()
plt.show()

print(f"\n📊 AUC-ROC: {roc_auc:.4f}")

# %% [markdown]
# ## 1️⃣4️⃣ Reporte de Clasificación
#
# ### 📝 Tarea:
# Genera un reporte de clasificación completo.
#
# ### 💡 Pista:
# - Usa `classification_report(y_test, y_pred)` de sklearn

# %%
# TU CÓDIGO AQUÍ: Genera el reporte de clasificación
print("\n📋 REPORTE DE CLASIFICACIÓN COMPLETO:\n")

# %% [markdown]
# ## 1️⃣5️⃣ Guardar el Modelo
#
# ### 📝 Tarea:
# Guarda el modelo entrenado y el scaler para uso futuro.
#
# ### 💡 Pistas:
# - Usa `model.save('nombre_archivo.keras')` para guardar el modelo
# - Usa `joblib.dump(scaler, 'nombre_archivo.pkl')` para guardar el scaler

# %%
# TU CÓDIGO AQUÍ: Guarda el modelo


print("💾 Modelo guardado")

# TU CÓDIGO AQUÍ: Guarda el scaler
import joblib


print("💾 Scaler guardado")

# %% [markdown]
# ## 1️⃣6️⃣ Ejemplos de Predicción
#
# ### 📝 Tarea:
# Muestra 10 ejemplos aleatorios del conjunto de test con sus predicciones.
#
# ### 💡 Pistas:
# - Usa `np.random.choice()` para seleccionar índices aleatorios
# - Haz predicciones con `model.predict()`
# - Compara con los valores reales

# %%
# TU CÓDIGO AQUÍ: Muestra ejemplos de predicción
print("🧪 EJEMPLOS DE PREDICCIÓN:\n")

# Selecciona 10 índices aleatorios


# Itera sobre los índices
for i, idx in enumerate(indices, 1):
    # Obtén el ejemplo
    
    
    # Haz la predicción
    
    
    # Compara con el valor real
    
    
    # Muestra el resultado

# %% [markdown]
# ---
#
# ## ✅ CHECKLIST FINAL
#
# Verifica que has completado todos los pasos:
#
# - [ ] 1. Instalación de librerías
# - [ ] 2. Importación correcta
# - [ ] 3. Carga del dataset
# - [ ] 4. Exploración de datos (EDA)
#   - [ ] Primeras filas
#   - [ ] Información general
#   - [ ] Distribución del target
#   - [ ] Análisis de valores faltantes
# - [ ] 5. Preprocesamiento completo
#   - [ ] Eliminación de columnas innecesarias
#   - [ ] Separación X/y
#   - [ ] Identificación de columnas
#   - [ ] Imputación de valores faltantes
#   - [ ] Encoding categórico
#   - [ ] División train/test
#   - [ ] Normalización
# - [ ] 6. Construcción del modelo
# - [ ] 7. Compilación del modelo
# - [ ] 8. Cálculo de class weights
# - [ ] 9. Entrenamiento
# - [ ] 10. Visualización del entrenamiento
# - [ ] 11. Evaluación en test
# - [ ] 12. Matriz de confusión
# - [ ] 13. Curva ROC
# - [ ] 14. Reporte de clasificación
# - [ ] 15. Guardado del modelo
# - [ ] 16. Ejemplos de predicción
#
# ---
#
# ## 🎯 PREGUNTAS DE REFLEXIÓN FINAL
#
# 1. **¿Por qué es importante usar múltiples métricas y no solo accuracy?**
#    - Respuesta: _________________________________________
#
# 2. **¿Cómo afecta el desbalanceo de clases al modelo? ¿Cómo lo manejamos?**
#    - Respuesta: _________________________________________
#
# 3. **¿Qué significa un Falso Positivo en este contexto? ¿Y un Falso Negativo?**
#    - FP: _________________________________________
#    - FN: _________________________________________
#
# 4. **¿Por qué usamos Dropout en la arquitectura?**
#    - Respuesta: _________________________________________
#
# 5. **¿Qué mejoras propondrías para el modelo?**
#    - Respuesta: _________________________________________
#
# ---
#
# ## 🚀 EXPERIMENTOS OPCIONALES
#
# Si has terminado el ejercicio, prueba con:
#
# 1. **Cambiar la arquitectura**: añade más capas o cambia el número de neuronas
# 2. **Ajustar Dropout**: prueba con valores diferentes (0.1, 0.5)
# 3. **Cambiar el batch_size**: prueba con 128, 512, 1024
# 4. **Diferentes optimizadores**: prueba SGD, RMSprop
# 5. **Feature engineering**: crea nuevas features combinando las existentes
# 6. **Early Stopping**: implementa para detener el entrenamiento automáticamente
# 7. **Ajustar el umbral de decisión**: en lugar de 0.5, prueba 0.3 o 0.7
#
# ---
#
# **¡Felicidades por completar el ejercicio!** 🎉🌧️
