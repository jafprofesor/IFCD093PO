# %% [markdown]
# # Preprocesamiento: Restaurant Tips Dataset
#
# ## 🎯 Objetivos de Aprendizaje
# - **Técnica Principal**: Análisis de Relaciones entre Variables + Predicción de Propinas
# - **Dataset**: Restaurant Tips (Tips dataset)
# - **Nivel**: Intermedio
#
# ## 📊 Contexto del Dataset
# El dataset de propinas contiene información sobre facturas y propinas en restaurantes. Es ideal para aprender:
# - **Análisis exploratorio** con variables mixtas (numéricas y categóricas)
# - **Visualizaciones avanzadas** para entender relaciones
# - **Preprocesamiento** de variables categóricas y numéricas
# - **Modelos de regresión** y clasificación
# - **Feature engineering** (crear nuevas variables)
#
# ## 💡 ¿Por qué Tips Dataset?
# - ✅ Variables mixtas reales (numéricas + categóricas)
# - ✅ Contexto familiar y fácil de interpretar
# - ✅ Problemas típicos del mundo real (outliers, distribuciones sesgadas)
# - ✅ Múltiples objetivos posibles (regresión y clasificación)
# - ✅ Oportunidades para feature engineering

# %%
# 📦 Importaciones


# Configuración de visualización

# %% [markdown]
# ## 📊 Paso 1: Carga y Exploración Inicial
#
# **🎯 Enfoque**: Comprensión inicial del dataset y identificación de oportunidades de preprocesamiento.

# %%
# Cargar el dataset
print("🍽️ Cargando Restaurant Tips Dataset...")

# El dataset está disponible en seaborn
tips = sns.load_dataset('tips')

# Información básica del dataset: número de registros, características y tipos de datos


# Verificar valores faltantes



# Mostrar las primeras filas
print(f"\n📋 Primeras 5 filas del dataset:")


# Información de tipos de datos
print(f"\n📊 Tipos de datos:")


# Información detallada del dataset
print(f"\n📋 Información detallada:")

# %% [markdown]
# ## 📊 Paso 2: Análisis Exploratorio de Datos (EDA)
#
# **🎯 Enfoque**: Análisis profundo de las distribuciones, relaciones y patrones en los datos.

# %%
# Estadísticas descriptivas
print("📊 ESTADÍSTICAS DESCRIPTIVAS")
print("=" * 40)

# Variables numéricas


# Variables categóricas


# Análisis de variables target potenciales
print(f"\n🎯 ANÁLISIS DE VARIABLES TARGET:")


# Calcular tip percentage

# %%
# Visualizaciones exploratorias


# 1. Distribución del monto de la cuenta
# Aqui se crea una figura con 2 filas y 3 columnas de subplots


# 2. Distribución de la propina
# Aquí se crea un histograma de la columna 'tip'


# 3. Distribución del porcentaje de propina
# Aquí se crea un histograma de la columna 'tip_percentage'


# 4. Propinas por día de la semana
# Aquí se crea un gráfico de barras del monto promedio de propina por día


# Añadir valores en las barras
# Aquí se añaden los valores encima de cada barra


# 5. Propinas por género del cliente
# Aquí se crea un gráfico de barras del monto promedio de propina por género


# Añadir valores en las barras
# Aquí se añaden los valores encima de cada barra


# 6. Propinas por si es fumador
# Aquí se crea un gráfico de barras del monto promedio de propina por hábito de fumar


# Añadir valores en las barras
# Aquí se añaden los valores encima de cada barra

# Ajustar el layout y mostrar la figura

# %% [markdown]
# ## 🔍 Paso 3: Análisis de Relaciones entre Variables
#
# **🎯 Enfoque**: Identificación de patrones y correlaciones que guíen el feature engineering.

# %%
# Análisis de correlaciones
print("🔗 ANÁLISIS DE CORRELACIONES")
print("=" * 40)

# Matriz de correlación
# Seleccionar solo las columnas numéricas relevantes



# Visualización de correlaciones
# Aquí se crea un mapa de calor para visualizar la matriz de correlación


# Análisis de correlación con la variable target (tip)
# Aquí se imprimen las correlaciones de 'tip' y 'tip_percentage' con otras variables
print(f"\n🎯 Correlaciones con 'tip' (monto de propina):")

# %%
# Análisis de relaciones categóricas con variables numéricas
print(f"📊 ANÁLISIS DE VARIABLES CATEGÓRICAS")
print("=" * 45)

# Box plots para variables categóricas
# Aquí se crean boxplots para analizar la distribución de 'tip' según variables categóricas


# 1. Propina por día de la semana
# Aqui se crea un boxplot de 'tip' por 'day'


# 2. Propina por tiempo
# Aquí se crea un boxplot de 'tip' por 'time'


# 3. Propina por género
# Aquí se crea un boxplot de 'tip' por 'sex' 


# 4. Propina por hábito de fumar
# Aquí se crea un boxplot de 'tip' por 'smoker'

# Ajustar el layout y mostrar la figura


# Análisis estadístico de diferencias entre grupos
print(f"\n📈 ANÁLISIS ESTADÍSTICO POR GRUPO")
print("=" * 45)

# Test de diferencia de medias para género
# Aquí se realiza un test t para comparar las propinas entre géneros


# Análisis por tiempo
# Aquí se realiza un test t para comparar las propinas entre tiempos (Lunch vs Dinner)

# %%
# Scatter plots para relaciones numéricas
# Aquí se crean scatter plots para analizar relaciones entre variables numéricas

# 1. Total Bill vs Tip
# Aquí se crea un scatter plot de 'total_bill' vs 'tip'


# Añadir línea de regresión
# Aquí se añade una línea de regresión al scatter plot


# 2. Size vs Tip
# Aquí se crea un scatter plot de 'size' vs 'tip'


# 3. Total Bill vs Tip Percentage
# Aquí se crea un scatter plot de 'total_bill' vs 'tip_percentage'

# Ajustar el layout y mostrar la figura


# Análisis de outliers
print(f"\n🔍 ANÁLISIS DE OUTLIERS")
print("=" * 30)

# Función para detectar outliers usando el método IQR
# Parametros:
#   data: DataFrame de pandas que contiene los datos
#   column: Nombre de la columna en la que se detectarán outliers

# %% [markdown]
# ## 🔧 Paso 4: Feature Engineering
#
# **🎯 Enfoque**: Creación de nuevas variables que mejoren el poder predictivo del modelo.

# %%
# Feature Engineering
print(f"🛠️ FEATURE ENGINEERING")
print("=" * 35)

# Crear una copia del dataset original para no modificarlo directamente


# 1. Categorizar el monto de la cuenta
# Aquí se categoriza 'total_bill' en categorías 'Low', 'Medium', 'High', 'Very_High'


# 2. Tamaño del grupo categorizado
# Aquí se categoriza 'size' en 'Single', 'Couple', 'Small_Group', 'Large_Group'


# 3. Indicadores binarios para días de fin de semana
# Aquí se crea un indicador binario 'is_weekend'


# 4. Indicador para cena
# Aquí se crea un indicador binario 'is_dinner'


# 5. Indicador para fumador
# Aquí se crea un indicador binario 'is_fumador'


# 6. Propina promedio por persona
# Aquí se crea la variable 'tip_per_person'


# 7. Interacción entre total_bill y size
# Aquí se crea la variable 'bill_per_person'


# 8. Códigos numéricos para variables categóricas
# Día de la semana
# Aquí se crea la variable 'day_encoded' 

# Aqui visualizamos un resumen del dataset después del feature engineering


# Mostrar las nuevas variables creadas
# Aquí se crea la lista de nuevas columnas


# Estadísticas de las nuevas variables numéricas
# Aquí se visualizan estadísticas descriptivas de las nuevas variables numéricas

# %%
# Visualización de nuevas variables
# Aquí se crea una figura con 2 filas y 3 columnas de subplots para visualizar las nuevas variables creadas


# 1. Distribución de bill_category
# Aqui se crea una gráfica de pastel para la distribución de 'bill_category'


# 2. Tip promedio por categoría de cuenta
# Aquí se crea una gráfica de barras para el tip promedio por categoría de cuenta


# 3. Propina por tamaño de grupo
# Aquí se crea un boxplot de 'tip' por 'size_category'


# 4. Comparación weekend vs weekday
# Aquí se crea una gráfica de barras para comparar el tip y tip_percentage entre weekend y weekday


# 5. Bill per person vs Tip per person
# Aquí se crea un scatter plot de 'bill_per_person' vs 'tip_per_person'


# 6. Heatmap de correlación de nuevas variables
# Aquí se crea un mapa de calor para visualizar las correlaciones entre las nuevas variables y 'tip'


# Ajustar el layout y mostrar la figura

# %% [markdown]
# ## 🔄 Paso 5: Preprocesamiento de Datos
#
# **🎯 Enfoque**: Preparación de los datos para los modelos de machine learning.

# %%
# Preprocesamiento para modelos
print(f"🔄 PREPROCESAMIENTO PARA MACHINE LEARNING")
print("=" * 50)

# Definir las features para los modelos
# Para predecir el monto de la propina (regresión)
# Aquí se definen las características a utilizar en el modelo de regresión


# Para predecir el porcentaje de propina (clasificación)
# Aquí se crea una variable categórica para el porcentaje de propina


# Preparar datasets
# Aqui se crean los datasets de features y targets para regresión y clasificación


# Para clasificación del porcentaje de propina
# Aquí se definen las características a utilizar en el modelo de clasificación

# Aqui visualizamos las formas de los datasets preparados


# Información de los datasets
# Aquí se imprimen las variables utilizadas y la distribución de clases en clasificación


# Verificar si hay valores faltantes en las features seleccionadas
# Aquí se verifica si hay valores faltantes en las características seleccionadas


# Estadísticas de las variables seleccionadas
# Aquí se imprimen las estadísticas descriptivas de las características utilizadas en regresión


# Separación train/test
# Aquí se separan los datos en conjuntos de entrenamiento y prueba para regresión

# Aquí se separan los datos en conjuntos de entrenamiento y prueba para clasificación


# Aqui visualizamos la división de los datos en train y test


# Escalado de características
# Aquí se escalan las características utilizando StandardScaler para regresión


# Aquí se escalan las características utilizando StandardScaler para clasificación


print(f"✅ Escalado completado para ambos datasets")

# %% [markdown]
# ## 🤖 Paso 6: Modelos de Regresión - Predicción del Monto de la Propina
#
# **🎯 Objetivo**: Predecir el monto de la propina usando diferentes algoritmos.

# %%
# Modelos de regresión
print(f"🤖 MODELOS DE REGRESIÓN - PREDICCIÓN DEL MONTO DE LA PROPINA")
print("=" * 65)

# Importar modelos y métricas
# Aqui se importan los modelos de regresión y las métricas necesarias


# Definir modelos
# Aquí se definen los modelos de regresión a utilizar


# Evaluación de modelos
# Aquí se evalúan los modelos de regresión


# Entrenamiento y evaluación de cada modelo con un bucle

    
    # Entrenar

    
    # Predicciones

    
    # Métricas

    
    # Cross-validation score

    # Almacenar resultados


# Mostrar resultados
# Aquí se muestran los resultados de la evaluación de los modelos de regresión


# Encontrar mejor modelo
# Aquí se encuentra el mejor modelo de regresión basado en el R² de test
# Usaremos el diccionario 'regression_results' para encontrar el modelo con el mayor R² en el conjunto de prueba

# Aquí se imprime el mejor modelo de regresión y sus métricas asociadas

# %%
# Visualización de resultados de regresión
# Aquí se crean varias visualizaciones para evaluar el rendimiento del mejor modelo de regresión


# 1. Comparación de métricas
# Aquí se crea una gráfica de barras para comparar las métricas de los modelos de regresión

# Obtener nombres de modelos y métricas

# Aqui se crean las listas de nombres de modelos y sus respectivas métricas


# 2. Predicciones vs valores reales del mejor modelo
# Aquí se crea un scatter plot para comparar las predicciones del mejor modelo con los valores reales


# 3. Residuales
# Aquí se crea un scatter plot para analizar los residuales del mejor modelo


# 4. Feature importance (si el modelo lo permite)
# Aquí se crea una gráfica de barras para mostrar la importancia de las características del mejor modelo

    # Aquí se crea una gráfica de barras horizontales para la importancia de las características

    # Para modelos lineales, mostrar coeficientes
    
# Ajustar el layout y mostrar la figura

# %% [markdown]
# ## 🤖 Paso 7: Modelos de Clasificación - Predicción del Porcentaje de Propina
#
# **🎯 Objetivo**: Clasificar el porcentaje de propina en categorías.

# %%
# Modelos de clasificación
print(f"🤖 MODELOS DE CLASIFICACIÓN - PREDICCIÓN DEL PORCENTAJE DE PROPINA")
print("=" * 70)

# Importar modelos y métricas


# Definir modelos
# Aquí se definen los modelos de clasificación a utilizar


# Evaluación de modelos
# Aquí se evalúan los modelos de clasificación


# Entrenamiento y evaluación de cada modelo con un bucle

    
    # Entrenar

    
    # Predicciones

    
    # Métricas

    
    # Cross-validation score


# Mostrar resultados
print(f"\n📊 RESULTADOS DE CLASIFICACIÓN:")
print("=" * 55)


# Encontrar mejor modelo
# Aquí se encuentra el mejor modelo de clasificación basado en la precisión de test
# Usaremos el diccionario 'classification_results' para encontrar el modelo con la mayor precisión en


# Aquí se imprime el mejor modelo de clasificación y su precisión en el conjunto de prueba


# Reporte de clasificación detallado
# Aquí se imprime un reporte de clasificación detallado para el mejor modelo de clasificación

# %%
# Visualización de resultados de clasificación
# Aquí se crean varias visualizaciones para evaluar el rendimiento del mejor modelo de clasificación


# 1. Comparación de accuracies
# Aquí se crea una gráfica de barras para comparar las accuracies de los modelos de clasificación




# 2. Matriz de confusión
# Aquí se crea un heatmap para visualizar la matriz de confusión del mejor modelo


# 3. Distribución de clases predichas vs reales
# Reindexar ambas series según todas las clases (target_names) para evitar mismatch cuando
# algunas clases no aparecen en las predicciones
# Aquí se crean las series de conteo para las clases reales y predichas


# Aquí se crean las barras para comparar la distribución de clases reales y predichas


# 4. Feature importance (si el modelo lo permite)
# Aquí se crea una gráfica de barras para mostrar la importancia de las características del mejor modelo

# Ajustar el layout y mostrar la figura

# %% [markdown]
# ## 🎓 Paso 8: Conclusiones y Análisis Final
#
# **🎯 Síntesis**: Evaluación del aprendizaje y insights del análisis.

# %%
# Conclusiones finales
print("🎓 CONCLUSIONES DEL ANÁLISIS DE RESTAURANT TIPS")
print("=" * 55)

print(f"\n📊 RESUMEN DEL DATASET:")
# Aquí se imprimen las estadísticas clave del dataset original y el dataset mejorado


print(f"\n🤖 MEJORES MODELOS ENCONTRADOS:")
print(f"\n📈 REGRESIÓN (Predicción del monto):")


print(f"\n📊 CLASIFICACIÓN (Categorización del %):")


print(f"\n🔍 INSIGHTS CLAVE DEL ANÁLISIS:")

# Insights de correlación
# Aquí se analizan las correlaciones clave relacionadas con la propina


print(f"\n💰 FACTORES QUE INFLUYEN EN LA PROPINA:")
# Aquí se imprimen los insights clave relacionados con los factores que influyen en la propina

# %% [markdown]
# ---
#
# ## 📚 Resumen de Técnicas Aplicadas
#
# | Técnica | Propósito | Resultado en Este Dataset |
# |---------|-----------|---------------------------|
# | **Análisis Exploratorio** | Comprender distribuciones y relaciones | Identificación de patrones de propinas |
# | **Feature Engineering** | Crear variables derivadas | bill_per_person, tip_per_person mejoraron modelos |
# | **Visualización** | Identificar insights visuales | Diferencias claras por día, tiempo, género |
# | **Preprocesamiento** | Preparar datos para ML | Scaling, encoding, train/test split |
# | **Regresión** | Predecir monto de propina | R² = 0.547 con Random Forest |
# | **Clasificación** | Categorizar porcentaje | Accuracy = 0.727 con Random Forest |
