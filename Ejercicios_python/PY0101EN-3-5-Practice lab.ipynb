# %% [markdown]
# <center>
#
# # Laboratorio de Práctica
#
# </center>

# %% [markdown]
# <center>
#
# # **Scenario: Text Analysis**
#
# </center>

# %% [markdown]
# Tiempo estimado necesario: **45** minutos

# %% [markdown]
# # ¿Qué es el análisis de texto?
# El análisis de texto, también conocido como minería de texto o analítica de texto, se refiere al proceso de extraer información significativa y conocimientos de datos textuales.

# %% [markdown]
# ## Objetivos
#
# Después de completar este laboratorio, podrás:
# - Usar comandos de Python para realizar análisis de texto.
# - Convertir el texto a minúsculas y luego encontrar y contar la frecuencia de todas las palabras únicas, así como una palabra específica.

# %% [markdown]
# ## Configuración

# %% [markdown]
# Para este laboratorio, usarás los siguientes tipos de datos:
# * Lista
# * Cadenas (Strings)
# * Clases y objetos

# %% [markdown]
# **Consideremos un escenario de la vida real donde estás analizando los comentarios de los clientes sobre un producto. Tienes un gran conjunto de datos de reseñas de clientes en forma de cadenas y deseas extraer información útil de ellas utilizando las tres tareas identificadas:**
#
# **Tarea 1. Cadena en minúsculas:**
# Deseas preprocesar los comentarios de los clientes convirtiendo todo el texto a minúsculas. Este paso ayuda a estandarizar el texto. Poner el texto en minúsculas te permite concentrarte en el contenido en lugar de en el uso específico de mayúsculas y minúsculas.
#
# **Tarea 2. Frecuencia de todas las palabras en una cadena dada:**
# Después de convertir el texto a minúsculas, deseas determinar la frecuencia de cada palabra en los comentarios de los clientes. Esta información te ayudará a identificar qué palabras se usan con más frecuencia, indicando los aspectos o temas clave que los clientes mencionan en sus reseñas. Al analizar las frecuencias de las palabras, puedes obtener información sobre los problemas más comunes planteados por los clientes.
#
# **Tarea 3. Frecuencia de una palabra específica:**
# Además de analizar las frecuencias generales de las palabras, deseas rastrear específicamente la frecuencia de una palabra particular que sea relevante para tu análisis. Por ejemplo, podrías estar interesado en monitorear con qué frecuencia aparece la palabra "reliable" (confiable) en las reseñas de los clientes para medir el sentimiento del cliente sobre la confiabilidad del producto. Al centrarte en la frecuencia de una palabra específica, puedes obtener una comprensión más profunda de las opiniones o preferencias de los clientes relacionadas con ese aspecto particular.
#
# Al realizar estas tareas en el conjunto de datos de comentarios de los clientes, puedes obtener información valiosa sobre el sentimiento del cliente

# %% [markdown]
# ----

# %% [markdown]
# <center>
#
# # Parte-A

# %% [markdown]
# <center>
#
# **Nota: En la Parte-A, no obtendrás ninguna salida, ya que solo estás almacenando la cadena y creando una clase.**
#     </center>

# %% [markdown]
# ## Paso 1: Definir una cadena
# "Lorem ipsum dolor! diam amet, consetetur Lorem magna. sed diam nonumy eirmod tempor. diam et labore? et diam magna. et diam amet." <br>
# **Pista: Usa una variable y almacena la cadena anterior.**

# %%
# Pulsa Shift+Enter para ejecutar el código
givenstring="Los clientes están muy satisfechos con el producto. El servicio al cliente es excelente y confiable. La calidad del producto es confiable y duradera. Algunos clientes mencionan que el precio es un poco alto, pero la mayoría está de acuerdo en que vale la pena por la calidad confiable que ofrece."

# %% [markdown]
# ### Para lograr las tareas mencionadas en el escenario, necesitas crear una clase con tres métodos diferentes.

# %% [markdown]
# ## Paso 2: Definir la clase y sus atributos

# %% [markdown]
# 1. Crea una clase llamada TextAnalyzer.
# 2. Define el método constructor `__init__` que toma un argumento de texto.

# %%
# Por favor no ejecutes esta celda de código ya que está incompleta y producirá un error.

# Vamos a crear una clase llamada TextAnalyzer para analizar texto.
class TextAnalyzer(object):
    # El método __init__ inicializa la clase con un parámetro 'text'.
    # Almacenarás el 'text' proporcionado como una variable de instancia.
    def __init__(self, text):

# %% [markdown]
# ----

# %% [markdown]
# ## Paso 3: Implementar un código para formatear el texto en minúsculas

# %% [markdown]
# 1. Dentro del constructor, convierte el argumento de texto a minúsculas usando el método `lower()`.
# 2. Luego, elimina los signos de puntuación (puntos, signos de exclamación, comas y signos de interrogación) del texto usando el método `replace()`.
# 3. Finalmente, asigna el texto formateado a un nuevo atributo llamado fmtText.
#
# **Aquí actualizarás la clase `TextAnalyzer` anterior con los puntos mencionados anteriormente.**

# %%
# Presiona Shift+Enter para ejecutar el código.
class TextAnalyzer(object):
    
    def __init__ (self, text):
        # quitar puntuación
        
        # convertir texto a minúsculas

# %% [markdown]
# <details><summary>Haz clic aquí para ver la Solución</summary>
#
# ```python
# class TextAnalyzer(object):
#
#     def __init__ (self, text):
#         # remove punctuation
#         formattedText = text.replace('.','').replace('!','').replace('?','').replace(',','')
#
#         # make text lowercase
#         formattedText = formattedText.lower()
#
#         self.fmtText = formattedText
#
# ```
#
# </details>

# %% [markdown]
# ----

# %% [markdown]
# ## Paso 4: Implementar un código para contar la frecuencia de todas las palabras únicas

# %% [markdown]
# * En este paso, implementarás el método `freqAll()` con los siguientes parámetros:
#      1. Dividir el atributo fmtText en palabras individuales usando el método `split()`.
#      2. Crear un diccionario vacío para almacenar la frecuencia de las palabras.
#      3. Iterar sobre la lista de palabras y actualizar el diccionario de frecuencia en consecuencia.
#      4. Usar el método `count` para contar la ocurrencia.
#      5. Devolver el diccionario de frecuencia.
#
# **Actualiza la clase `TextAnalyzer` anterior con los puntos mencionados anteriormente.**

# %%
# Pulsa Shift+Enter para ejecutar el código
class TextAnalyzer(object):
    
    def __init__ (self, text):
        # quitar puntuación
        
        # convertir texto a minúsculas
        
    def freqAll(self):        
        # dividir texto en palabras
        
        # Crear diccionario para almacenar frecuencias

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# class TextAnalyzer(object):
#
#     def __init__ (self, text):
#         # remove punctuation
#         formattedText = text.replace('.','').replace('!','').replace('?','').replace(',','')
#
#         # make text lowercase
#         formattedText = formattedText.lower()
#
#         self.fmtText = formattedText
#
#     def freqAll(self):
#         # split text into words
#         wordList = self.fmtText.split(' ')
#
#         # Create dictionary
#         freqMap = {}
#         for word in set(wordList): # use set to remove duplicates in list
#             freqMap[word] = wordList.count(word)
#
#         return freqMap
# ```
#
# </details>

# %% [markdown]
# ----

# %% [markdown]
# ## Paso 5: Implementar un código para contar la frecuencia de una palabra específica

# %% [markdown]
# En el paso 5, debes implementar el método `freqOf(word)` que toma un argumento de palabra:
#    1. Crear un método y pasar la palabra que se necesita encontrar.
#    2. Obtener el método `freqAll` para buscar el conteo y verificar si esa palabra está en la lista.
#    3. Devolver el conteo. Si no se encuentra la palabra, el conteo devuelto es 0.
#
# **Actualiza la clase `TextAnalyzer` anterior con los puntos mencionados anteriormente.**

# %%
# Pulsa Shift+Enter para ejecutar el código
class TextAnalyzer(object):
    
    def __init__ (self, text):
        # quitar puntuación 
       
        # convertir texto a minúsculas
        
    def freqAll(self):        
        # dividir texto en palabras
        
        # Crear diccionario para almacenar frecuencias
           
    def freqOf(self,word):
        # obtener mapa de frecuencias

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# class TextAnalyzer(object):
#
#     def __init__ (self, text):
#         # remove punctuation
#         formattedText = text.replace('.','').replace('!','').replace('?','').replace(',','')
#
#         # make text lowercase
#         formattedText = formattedText.lower()
#
#         self.fmtText = formattedText
#
#     def freqAll(self):
#         # split text into words
#         wordList = self.fmtText.split(' ')
#
#         # Create dictionary
#         freqMap = {}
#         for word in set(wordList): # use set to remove duplicates in list
#             freqMap[word] = wordList.count(word)
#
#         return freqMap
#
#     def freqOf(self,word):
#         # get frequency map
#         freqDict = self.freqAll()
#
#         if word in freqDict:
#             return freqDict[word]
#         else:
#             return 0
# ```
# </details>

# %% [markdown]
# ### Ahora, has creado con éxito una clase con tres métodos.

# %% [markdown]
# <center>
#
# # Parte-B

# %% [markdown]
# <center>
#
# **En la Parte B, llamarás a las funciones creadas en la Parte A, permitiendo que las funciones se ejecuten y generen salida.**
#     </center>

# %% [markdown]
# ## Paso 1: Crear una instancia de la clase TextAnalyzer
# * Instanciar la clase TextAnalyzer pasando la cadena dada como argumento.

# %%
# Escribe tu código abajo y presiona Shift+Enter para ejecutar

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# analyzed = TextAnalyzer(givenstring)
# ```
# </details>

# %% [markdown]
# ## Paso 2: Llamar a la función que convierte los datos a minúsculas

# %%
# Escribe tu código abajo y presiona Shift+Enter para ejecutar

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# print("Formatted Text:", analyzed.fmtText)
# ```
# </details>

# %% [markdown]
# Has convertido con éxito la cadena a minúsculas.

# %% [markdown]
# ## Paso 3: Llamar a la función que cuenta la frecuencia de todas las palabras únicas de los datos

# %%
# Escribe tu código abajo y presiona Shift+Enter para ejecutar

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# freqMap = analyzed.freqAll()
# print(freqMap)
# ```
# </details>

# %% [markdown]
# Has calculado con éxito la frecuencia de todas las palabras únicas en la cadena.

# %% [markdown]
# ## Paso 4: Llamar a la función que cuenta la frecuencia de una palabra específica
# Aquí, llamarás a la función que cuenta la frecuencia de la palabra "lorem".
# <br>
#
# Imprime la salida.**

# %%
# Escribe tu código abajo y presiona Shift+Enter para ejecutar

# %% [markdown]
# <details><summary>Haz clic aquí para ver la solución</summary>
#
# ```python
# word = "lorem"
# frequency = analyzed.freqOf(word)
# print("The word",word,"appears",frequency,"times.")
# ```
# </details>

# %% [markdown]
# Has calculado con éxito la frecuencia de todas las palabras especificadas.

# %% [markdown]
# ----

# %% [markdown]
# <!--
# ## Change Log
# -->
