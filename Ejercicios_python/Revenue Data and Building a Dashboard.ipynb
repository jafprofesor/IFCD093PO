# %% [markdown]
# # Extracción y Visualización de Datos de Acciones
#
# ## Descripción

# %% [markdown]
# Este proyecto tiene como objetivo extraer datos históricos de acciones y presentarlos visualmente mediante gráficos. La extracción de datos esenciales de un conjunto de datos y su visualización son habilidades fundamentales en ciencia de datos, ya que permiten a las personas tomar decisiones informadas basadas en los datos. En esta asignación, extraerás datos de acciones y los mostrarás en gráficos para su análisis.

# %% [markdown]
# <h2>Tabla de Contenidos</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>Definir una Función que Crea un Gráfico</li>
#         <li>Pregunta 1: Usar yfinance para Extraer Datos de Acciones</li>
#         <li>Pregunta 2: Usar Webscraping para Extraer Datos de Ingresos de Tesla</li>
#         <li>Pregunta 3: Usar yfinance para Extraer Datos de Acciones</li>
#         <li>Pregunta 4: Usar Webscraping para Extraer Datos de Ingresos de GME</li>
#         <li>Pregunta 5: Graficar el Gráfico de Acciones de Tesla</li>
#         <li>Pregunta 6: Graficar el Gráfico de Acciones de GameStop</li>
#     </ul>
# <p>
#     Tiempo Estimado Necesario: <strong>30 min</strong></p>
# </div>
#
# <hr>

# %% [markdown]
# ***Nota***:- Si estás trabajando localmente usando anaconda, por favor descomenta el siguiente código y ejecútalo.
# Usa la versión según tu versión de Python.

# %%
# %pip install yfinance
# %pip install bs4
# %pip install nbformat
# %pip install matplotlib

# %%
import yfinance as yf
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# En Python, puedes ignorar las advertencias usando el módulo warnings. Puedes usar la función filterwarnings para filtrar o ignorar mensajes de advertencia específicos o categorías.

# %%
import warnings
# Ignorar todas las advertencias de tipo FutureWarning
warnings.filterwarnings("ignore", category=FutureWarning)

# %% [markdown]
# ## Definir Función de Graficación

# %% [markdown]
# En esta sección, definimos la función `make_graph`. **No necesitas saber cómo funciona la función, solo debes preocuparte por las entradas. Toma un dataframe con datos de acciones (el dataframe debe contener las columnas Date y Close), un dataframe con datos de ingresos (el dataframe debe contener las columnas Date y Revenue), y el nombre de la acción.**

# %%
# La función make_graph ha sido modificada para usar Matplotlib para gráficos estáticos. Anteriormente, usaba Plotly para generar dashboards interactivos, lo que causaba problemas al subir el notebook en la entrega de la tarea MARK.



import matplotlib.pyplot as plt

def make_graph(stock_data, revenue_data, stock):
    stock_data_specific = stock_data[stock_data.Date <= '2021-06-14']
    revenue_data_specific = revenue_data[revenue_data.Date <= '2021-04-30']

    fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=True)

    # Stock price
    axes[0].plot(pd.to_datetime(stock_data_specific.Date), stock_data_specific.Close.astype("float"), label="Share Price", color="blue")
    axes[0].set_ylabel("Price ($US)")
    axes[0].set_title(f"{stock} - Historical Share Price")

    # Revenue
    axes[1].plot(pd.to_datetime(revenue_data_specific.Date), revenue_data_specific.Revenue.astype("float"), label="Revenue", color="green")
    axes[1].set_ylabel("Revenue ($US Millions)")
    axes[1].set_xlabel("Date")
    axes[1].set_title(f"{stock} - Historical Revenue")

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Usar la Función de Graficación
#
# Utiliza la función `make_graph` que ya hemos definido. Necesitarás invocarla en las preguntas 5 y 6 para mostrar los gráficos y crear el dashboard.
# > **Nota: No necesitas redefinir la función para graficar en ninguna otra parte de este notebook; simplemente usa la función existente.**

# %% [markdown]
# ## Pregunta 1: Usar yfinance para Extraer Datos de Acciones

# %% [markdown]
# Usando la función Ticker ingresa el símbolo de ticker de la acción de la cual queremos extraer datos para crear un objeto ticker. La acción es Tesla y su símbolo de ticker es TSLA.

# %%
tesla = yf.Ticker("TSLA")

# %% [markdown]
# Utilizando el objeto ticker y la función history extrae información de acciones y guárdala en un dataframe llamado tesla_data. Establece el parámetro period en "max" para obtener información del máximo período de tiempo posible.

# %%
tesla_data = tesla.history(period="max")

# %% [markdown]
# **Reinicia el índice** usando la función `reset_index(inplace=True)` en el DataFrame tesla_data y muestra las primeras cinco filas del dataframe `tesla_data` usando la función `head`. Toma una captura de pantalla de los resultados y el código desde el inicio de la Pregunta 1 hasta los resultados a continuación.

# %%
tesla_data.reset_index(inplace=True)
tesla_data.head()

# %% [markdown]
# ## Pregunta 2: Usar Webscraping para Extraer Datos de Ingresos de Tesla

# %% [markdown]
# Usa la librería requests para descargar la página web https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm Guarda el texto de la respuesta como una variable llamada html_data.

# %%
url= " https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/revenue.htm"
html_data=requests.get(url).text

# %% [markdown]
# Analiza los datos html usando beautiful_soup con un parser, es decir html5lib o html.parser.

# %%
# Instalo la librería html5lib
# %pip install html5lib

# %%
soup = BeautifulSoup(html_data,"html5lib")

# %% [markdown]
# Utilizando BeautifulSoup o la función read_html extrae la tabla con Tesla Revenue y guárdala en un dataframe llamado tesla_revenue. El dataframe debe tener las columnas Date y Revenue.

# %% [markdown]
# <details><summary>Instrucciones paso a paso</summary>
#
# ```
#
# Aquí están las instrucciones paso a paso:
#
# 1. Crear un DataFrame Vacío
# 2. Encontrar la Tabla Relevante
# 3. Verificar la Tabla de Ingresos Trimestrales de Tesla
# 4. Iterar a Través de las Filas en el Cuerpo de la Tabla
# 5. Extraer Datos de las Columnas
# 6. Agregar Datos al DataFrame
#
# ```
# </details>

# %% [markdown]
# <details><summary>Haz clic aquí si necesitas ayuda para localizar la tabla</summary>
#
# ```
#
# A continuación se muestra el código para aislar la tabla, ahora necesitarás recorrer las filas y columnas como en el laboratorio anterior
#
# soup.find_all("tbody")[1]
#
# Si deseas usar la función read_html, la tabla se encuentra en el índice 1
#
# Nos estamos enfocando en los ingresos trimestrales en el laboratorio.

# %%
tesla_revenue = pd.read_html(url, match="Tesla Quarterly Revenue", flavor='bs4')[0]
tesla_revenue.columns = ['Date', 'Revenue']

# %% [markdown]
# Ejecuta la siguiente línea para eliminar la coma y el signo de dólar de la columna Revenue.

# %%
tesla_revenue["Revenue"] = tesla_revenue['Revenue'].str.replace(',|\\$',"",regex=True)

# %% [markdown]
# Ejecuta las siguientes líneas para eliminar valores nulos o cadenas vacías en la columna Revenue.

# %%
tesla_revenue.dropna(inplace=True)

tesla_revenue = tesla_revenue[tesla_revenue['Revenue'] != ""]

# %% [markdown]
# Muestra las últimas 5 filas del dataframe tesla_revenue usando la función tail. Toma una captura de pantalla de los resultados.

# %%
tesla_revenue.tail()

# %% [markdown]
# ## Pregunta 3: Usar yfinance para Extraer Datos de Acciones

# %% [markdown]
# Utilizando la función Ticker ingresa el símbolo de ticker de la acción de la cual queremos extraer datos para crear un objeto ticker. La acción es GameStop y su símbolo de ticker es GME.

# %%
gme = yf.Ticker("GME")

# %% [markdown]
# Utilizando el objeto ticker y la función history extrae información de acciones y guárdala en un dataframe llamado gme_data. Establece el parámetro period en "max" para obtener información del máximo período de tiempo posible.

# %%
gme_data = gme.history(period="max")

# %% [markdown]
# **Reinicia el índice** usando la función `reset_index(inplace=True)` en el DataFrame gme_data y muestra las primeras cinco filas del dataframe `gme_data` usando la función `head`. Toma una captura de pantalla de los resultados y el código desde el inicio de la Pregunta 3 hasta los resultados a continuación.

# %%
gme_data.reset_index(inplace=True)
gme_data.head()

# %% [markdown]
# ## Pregunta 4: Usar Webscraping para Extraer Datos de Ingresos de GME

# %% [markdown]
# Utiliza la librería requests para descargar la página web https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html. Guarda el texto de la respuesta como una variable llamada html_data_2.

# %%
url2 = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-PY0220EN-SkillsNetwork/labs/project/stock.html"
html_data_2 = requests.get(url2).text

# %% [markdown]
# Analiza los datos html usando beautiful_soup con un parser, es decir html5lib o html.parser.

# %%
soup_2 = BeautifulSoup(html_data_2, "html5lib")

# %% [markdown]
# Utilizando BeautifulSoup o la función read_html extrae la tabla con los Ingresos de GameStop y guárdala en un dataframe llamado gme_revenue. El dataframe debe tener las columnas Date y Revenue. Asegúrate de que la coma y el signo de dólar sean eliminados de la columna Revenue.

# %% [markdown]
# > **Nota: Usa el método similar al que hiciste en la pregunta 2.**

# %% [markdown]
# <details><summary>Haz clic aquí si necesitas ayuda para localizar la tabla</summary>
#
# ```
#
# A continuación se muestra el código para aislar la tabla, ahora necesitarás recorrer las filas y columnas como en el laboratorio anterior
#
# soup_2.find_all("tbody")[1]
#
# Si deseas usar la función read_html, la tabla se encuentra en el índice 1
#
#
# ```
#
# </details>

# %%
gme_revenue = pd.read_html(url2, match="GameStop Quarterly Revenue", flavor='bs4')[0]
gme_revenue.columns = ['Date', 'Revenue']
gme_revenue.head()

# %% [markdown]
# Elimina la coma y el signo de dólar, así como los valores nulos o cadenas vacías de la columna Revenue.

# %%
gme_revenue["Revenue"] = gme_revenue['Revenue'].str.replace(',|\\$',"",regex=True)

# %% [markdown]
# Muestra las últimas cinco filas del dataframe gme_revenue usando la función tail. Toma una captura de pantalla de los resultados.

# %%
gme_revenue.tail()

# %% [markdown]
# ## Pregunta 5: Graficar el Gráfico de Acciones de Tesla

# %% [markdown]
# Utiliza la función make_graph para graficar los Datos de Acciones de Tesla, y también proporciona un título para el gráfico. Nota que el gráfico solo mostrará datos hasta junio de 2021.

# %% [markdown]
# <details><summary>Pista</summary>
#
# ```
#
# Solo necesitas invocar la función make_graph con el parámetro requerido para imprimir los gráficos. La estructura para llamar a la función `make_graph` es `make_graph(tesla_data, tesla_revenue, 'Tesla')`.
#
# ```
#
# </details>

# %%
make_graph(tesla_data, tesla_revenue, 'Tesla')

# %% [markdown]
# ## Pregunta 6: Graficar el Gráfico de Acciones de GameStop

# %% [markdown]
# Utiliza la función `make_graph` para graficar los Datos de Acciones de GameStop, y también proporciona un título para el gráfico. La estructura para llamar a la función `make_graph` es `make_graph(gme_data, gme_revenue, 'GameStop')`. Nota que el gráfico solo mostrará datos hasta junio de 2021.

# %% [markdown]
# <details><summary>Pista</summary>
#
# ```
#
# Solo necesitas invocar la función make_graph con el parámetro requerido para imprimir los gráficos. La estructura para llamar a la función `make_graph` es `make_graph(gme_data, gme_revenue, 'GameStop')`.
#
# ```
#
# </details>

# %%
make_graph(gme_data, gme_revenue, 'GameStop')
