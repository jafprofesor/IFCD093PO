# %% [markdown]
# # Proyecto Práctico: Extracción y procesamiento de datos del PIB

# %% [markdown]
# ## Escenario del Proyecto:

# %% [markdown]
# URL: https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29

# %% [markdown]
# ## Objetivos

# %% [markdown]
# ---

# %% [markdown]
# ## Descargo de responsabilidad

# %% [markdown]
# # Configuración

# %% [markdown]
# Para este laboratorio, usaremos las siguientes bibliotecas:
#
# *   [`pandas`](https://pandas.pydata.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) para gestionar los datos.
# *   [`numpy`](https://numpy.org/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMML0187ENSkillsNetwork31430127-2021-01-01) para operaciones matemáticas.

# %%
# Instalar paquetes requeridos
# %pip install pandas numpy 
# %pip install lxml

# %% [markdown]
# ### Importando Bibliotecas Requeridas

# %%
import numpy as np
import pandas as pd

#  También puedes usar esta sección para suprimir las advertencias generadas por tu código:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# %% [markdown]
# ---

# %% [markdown]
# # Ejercicios

# %%
URL="https://web.archive.org/web/20230902185326/https://en.wikipedia.org/wiki/List_of_countries_by_GDP_%28nominal%29"

# %% [markdown]
# Puedes usar la biblioteca Pandas para extraer la tabla requerida directamente como un DataFrame. Ten en cuenta que la tabla requerida es la tercera en el sitio web, como se muestra en la imagen a continuación.

# %%
# Extraer tablas de la página web usando Pandas. Retener la tabla número 3 como el dataframe requerido.

# Reemplazar los encabezados de columna con números de columnas enteros comenzando desde 0.
df.columns = range(df.shape[1])

# Retener las columnas con índice 0 y 2 (nombre del país y valor del PIB citado por el FMI)

# Retener las filas con índice 1 a 10, indicando las 10 principales economías del mundo.

# Asignar nombres de columna como "País" y "PIB (Millones USD)"

# %% [markdown]
# <summary>Haz clic aquí para ver la solución</summary>

# %% [markdown]
# ### Ejercicio 2

# %%
# Cambiar el tipo de datos de la columna 'PIB (Millones USD)' a entero. Usar el método astype().

# Convertir el valor del PIB en Millones USD a Miles de Millones USD

# Usar el método numpy.round() para redondear el valor a 2 decimales.
# Renombrar el encabezado de la columna de 'PIB (Millones USD)' a 'PIB (Miles de Millones USD)'

# %% [markdown]
# <summary>Haz clic aquí para ver la solución</summary>

# %% [markdown]
# ### Ejercicio 3

# %% [markdown]
# Carga el DataFrame al archivo CSV llamado "Largest_economies.csv"

# %%
# Cargar el DataFrame al archivo CSV llamado "Largest_economies.csv"

# %% [markdown]
# <summary>Haz clic aquí para ver la solución</summary>

# %% [markdown]
# ---
