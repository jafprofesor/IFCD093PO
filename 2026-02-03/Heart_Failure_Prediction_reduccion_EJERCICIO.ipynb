# %% [markdown]
# ## 📚 EJERCICIO: Aplicación de Técnicas de Reducción de Dimensiones en el Dataset Heart
#
# ### 🎯 Objetivos del Ejercicio
#
# En este ejercicio aprenderás a:
# 1. Aplicar técnicas de reducción de dimensionalidad (PCA, t-SNE, UMAP)
# 2. Visualizar datos de alta dimensión en 2D
# 3. Aplicar algoritmos de clustering (k-Means, Agglomerative, DBSCAN)
# 4. Evaluar la calidad de los clusters con métricas
# 5. Interpretar resultados en un contexto clínico
#
# ### 📊 Dataset
#
# Trabajaremos con el dataset **Heart Disease Prediction**, que contiene información de pacientes para predecir enfermedad cardíaca.

# %% [markdown]
# ---
# ## Parte 1: Importación de Librerías y Carga de Datos
#
# ### 📝 Instrucciones:
#
# Completa el código para importar todas las librerías necesarias.

# %%
# TAREA 1.1: Importar librerías básicas
# ¿Por qué? Necesitamos herramientas para manipular datos, crear gráficos y aplicar ML

# TODO: Importa numpy con alias 'np' (para operaciones numéricas)
# TODO: Importa pandas con alias 'pd' (para manipulación de datos tabulares)
# TODO: Importa matplotlib.pyplot con alias 'plt' (para visualizaciones)
# TODO: Importa seaborn con alias 'sns' (para gráficos estadísticos avanzados)



# TAREA 1.2: Importar herramientas de preprocesamiento
# ¿Por qué? Necesitamos estandarizar los datos antes de reducción dimensional

# TODO: Importa StandardScaler desde sklearn.preprocessing
# StandardScaler normaliza las características para que tengan media 0 y desviación estándar 1



# TAREA 1.3: Importar técnicas de reducción de dimensionalidad
# ¿Por qué? Son las técnicas principales que estudiaremos

# TODO: Importa PCA desde sklearn.decomposition
# PCA: Análisis de Componentes Principales - reducción lineal

# TODO: Importa TSNE desde sklearn.manifold  
# t-SNE: t-Distributed Stochastic Neighbor Embedding - reducción no lineal



# TAREA 1.4: Importar algoritmos de clustering
# ¿Por qué? Los usaremos para agrupar pacientes en perfiles de riesgo

# TODO: Importa KMeans desde sklearn.cluster
# k-Means: Clustering por centroides

# TODO: Importa AgglomerativeClustering desde sklearn.cluster
# Clustering jerárquico aglomerativo

# TODO: Importa DBSCAN desde sklearn.cluster
# DBSCAN: Clustering basado en densidad



# TAREA 1.5: Importar métricas de evaluación
# ¿Por qué? Para medir la calidad de nuestros clusters

# TODO: Importa silhouette_score desde sklearn.metrics
# Mide qué tan bien separados están los clusters

# TODO: Importa adjusted_rand_score desde sklearn.metrics
# Mide concordancia entre clusters y etiquetas reales

# TODO: Importa confusion_matrix desde sklearn.metrics
# Para crear matrices de confusión



# TAREA 1.6: Configurar warnings y magic commands
import warnings
warnings.filterwarnings('ignore')

# TAREA 1.7: Intentar importar UMAP (opcional)
# ¿Por qué? UMAP es una técnica avanzada de reducción que puede no estar instalada

try:
    import umap
    UMAP_AVAILABLE = True
except ImportError:
    UMAP_AVAILABLE = False
    print('⚠️ UMAP no está instalado. Para instalarlo: pip install umap-learn')

# TAREA 1.8: Cargar el dataset
# ¿Por qué? Es el primer paso para cualquier análisis de datos

# TODO: Lee el archivo 'heart.csv' usando pd.read_csv() y guárdalo en 'df'



# TODO: Imprime las dimensiones del dataset con df.shape
print('Dimensiones del dataset Heart:', ___)

# TODO: Imprime los nombres de las columnas con df.columns.tolist()
print('Características del dataset Heart:', ___)

# TODO: Muestra las primeras 5 filas con df.head()
print(___)

# TAREA 1.9: Configurar estilo de gráficos
# TODO: Establece el estilo de seaborn a 'whitegrid'


# Magic command para mostrar gráficos en el notebook
# %matplotlib inline

# %% [markdown]
# ---
# ## Parte 2: Preparación de Datos
#
# ### 📝 Instrucciones:
#
# Antes de aplicar reducción dimensional, debemos preparar los datos correctamente.

# %%
# TAREA 2.1: Convertir variables categóricas a dummies
# ¿Por qué? Los algoritmos de ML necesitan datos numéricos
# ¿Qué hace pd.get_dummies? Convierte variables categóricas en columnas binarias (0 o 1)
# ¿Por qué drop_first=True? Evita multicolinealidad eliminando una categoría redundante

# TODO: Aplica pd.get_dummies() al dataframe 'df' con drop_first=True
df = ___

# TODO: Imprime las nuevas dimensiones
print('Dimensiones tras get_dummies:', ___)

# TODO: Imprime las nuevas columnas
print('Características tras get_dummies:', ___)

# TODO: Muestra las primeras filas del dataframe transformado
print(___)

# %% [markdown]
# ---
# ## Parte 3: Separación de Características y Target, y Estandarización
#
# ### 📝 Instrucciones:
#
# Separar las características (X) del target (y) y estandarizar los datos.

# %%
# TAREA 3.1: Separar características (X) y target (y)
# ¿Por qué separamos? X son las variables predictoras, y es lo que queremos predecir

# TODO: Crea X_heart eliminando la columna 'HeartDisease' de df y convierte a numpy array con .values
X_heart = ___

# TODO: Crea y_heart con solo la columna 'HeartDisease' como numpy array
y_heart = ___

# TAREA 3.2: Estandarizar las características
# ¿Por qué estandarizar? Las técnicas de reducción dimensional son sensibles a la escala
# ¿Qué hace StandardScaler? Transforma cada característica para tener media=0 y std=1
# Esto asegura que todas las características contribuyan equitativamente

# TODO: Crea un objeto StandardScaler
scaler = ___

# TODO: Ajusta y transforma X_heart usando .fit_transform()
X_heart_scaled = ___

print('✅ Datos preparados y estandarizados')
print(f'Dimensiones de X: {X_heart.shape}')
print(f'Dimensiones de y: {y_heart.shape}')

# %% [markdown]
# ---
# ## Parte 4: Aplicación de Técnicas de Reducción de Dimensionalidad
#
# ### 📝 Instrucciones:
#
# Aplicaremos tres técnicas diferentes y las visualizaremos.

# %%
# CONFIGURACIÓN
dimensiones_pca_heart = 2  # Reduciremos a 2D para visualización

# ============================================================================
# TÉCNICA 1: PCA (Principal Component Analysis)
# ============================================================================
# ¿Qué es PCA? Encuentra nuevas dimensiones (componentes principales) que 
# capturan la máxima varianza de los datos
# ¿Es lineal o no lineal? LINEAL - solo puede capturar relaciones lineales
# ¿Cuándo usarlo? Cuando queremos reducción rápida y los datos tienen relaciones lineales

# TAREA 4.1: Crear y aplicar PCA

# TODO: Crea un objeto PCA con n_components=2 y random_state=42
pca_heart = ___

# TODO: Ajusta y transforma X_heart_scaled usando .fit_transform()
X_heart_pca = ___

print('Dimensiones originales:', X_heart.shape)
print('Dimensiones tras PCA:', X_heart_pca.shape)

# TODO: Imprime la varianza explicada con pca_heart.explained_variance_ratio_
# ¿Qué significa? % de información original capturada por cada componente
print('Varianza explicada:', np.round(___, 3))

# TAREA 4.2: Visualizar PCA
# ¿Por qué visualizar? Para ver cómo se separan las clases en el espacio reducido

# TODO: Crea una figura de 8x6 pulgadas
plt.figure(figsize=(___, ___))

# TODO: Crea un scatter plot:
# - x: primera columna de X_heart_pca (índice 0)
# - y: segunda columna de X_heart_pca (índice 1)
# - c: y_heart (para colorear por clase)
# - cmap='tab10' (mapa de colores)
# - alpha=0.8 (transparencia)
scatter = plt.scatter(___, ___, c=___, cmap=___, alpha=___)

# TODO: Añade título, etiquetas de ejes y leyenda
plt.title('PCA 2D - Heart Disease Prediction')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.legend(*scatter.legend_elements(), title='Clases')
plt.show()

# ============================================================================
# TÉCNICA 2: t-SNE (t-Distributed Stochastic Neighbor Embedding)
# ============================================================================
# ¿Qué es t-SNE? Reduce dimensiones preservando similitudes locales entre puntos
# ¿Es lineal o no lineal? NO LINEAL - puede capturar estructuras complejas
# ¿Cuándo usarlo? Para visualización de estructuras complejas y no lineales
# ⚠️ Limitación: No preserva distancias globales, solo locales

# TAREA 4.3: Crear y aplicar t-SNE

# TODO: Crea un objeto TSNE con:
# - n_components=2
# - perplexity=30 (afecta el equilibrio entre estructura local/global)
# - random_state=42
tsne_heart = ___

# TODO: Aplica t-SNE a X_heart_scaled con .fit_transform()
X_heart_tsne = ___

# TAREA 4.4: Visualizar t-SNE

# TODO: Crea la visualización similar a PCA pero con X_heart_tsne
plt.figure(figsize=(8, 6))
scatter = plt.scatter(___, ___, c=___, cmap='tab10', alpha=0.8)
plt.title('t-SNE 2D - Heart Disease Prediction')
plt.xlabel('t-SNE1')
plt.ylabel('t-SNE2')
plt.legend(*scatter.legend_elements(), title='Clases')
plt.show()

# ============================================================================
# TÉCNICA 3: UMAP (Uniform Manifold Approximation and Projection)
# ============================================================================
# ¿Qué es UMAP? Técnica moderna que preserva estructura local Y global
# ¿Es lineal o no lineal? NO LINEAL - similar a t-SNE pero mejor
# ¿Ventajas sobre t-SNE? Más rápido, preserva mejor la estructura global
# ¿Cuándo usarlo? Para datasets grandes y cuando queremos preservar más información

# TAREA 4.5: Crear y aplicar UMAP (solo si está disponible)

if UMAP_AVAILABLE:
    # TODO: Crea un objeto UMAP con n_components=2 y random_state=42
    umap_reducer_heart = ___
    
    # TODO: Aplica UMAP a X_heart_scaled
    X_heart_umap = ___
    
    # TAREA 4.6: Visualizar UMAP
    # TODO: Crea la visualización de UMAP
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(___, ___, c=___, cmap='tab10', alpha=0.8)
    plt.title('UMAP 2D - Heart Disease Prediction')
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.legend(*scatter.legend_elements(), title='Clases')
    plt.show()
    
    print('\n✅ Técnicas de reducción dimensional aplicadas con éxito')
else:
    print('⚠️ UMAP no disponible. Instala con: pip install umap-learn')

# %% [markdown]
# ---
# ## Parte 5: Aplicación de Algoritmos de Clustering en UMAP
#
# ### 📝 Instrucciones:
#
# Aplicaremos clustering sobre los datos reducidos con UMAP para encontrar grupos de pacientes.

# %%
if UMAP_AVAILABLE:
    
    # ========================================================================
    # ALGORITMO 1: k-Means
    # ========================================================================
    # ¿Qué es k-Means? Algoritmo que agrupa datos en k clusters basándose en centroides
    # ¿Cómo funciona? Asigna cada punto al centroide más cercano iterativamente
    # ¿Ventajas? Rápido, simple, funciona bien con clusters esféricos
    # ¿Limitaciones? Necesitas especificar k, sensible a outliers
    
    # TAREA 5.1: Aplicar k-Means
    
    # TODO: Crea un objeto KMeans con n_clusters=2 y random_state=42
    # ¿Por qué n_clusters=2? Porque tenemos 2 clases (con/sin enfermedad)
    kmeans_umap = ___
    
    # TODO: Ajusta y predice clusters con .fit_predict() sobre X_heart_umap
    y_umap_kmeans = ___
    
    # TAREA 5.2: Evaluar k-Means con métricas
    
    # TODO: Calcula Adjusted Rand Index comparando y_heart con y_umap_kmeans
    # ¿Qué mide ARI? Similitud entre clusters y clases reales (1=perfecto, 0=aleatorio)
    ari_umap = ___
    print(f'Adjusted Rand Index (k-Means): {ari_umap:.3f}')
    
    # TODO: Calcula Silhouette Score con X_heart_umap y y_umap_kmeans
    # ¿Qué mide Silhouette? Qué tan bien separados están los clusters (1=perfecto)
    sil_umap = ___
    print(f'Silhouette Score (k-Means): {sil_umap:.3f}')
    
    # TAREA 5.3: Visualizar clusters de k-Means
    
    # TODO: Crea scatter plot coloreado por clusters (y_umap_kmeans)
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(___, ___, c=___, cmap='tab10', alpha=0.8)
    plt.title('k-Means Clusters en UMAP - Heart Disease')
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.legend(*scatter.legend_elements(), title='Clusters k-Means')
    plt.show()
    
    # ========================================================================
    # ALGORITMO 2: Agglomerative Clustering (Jerárquico)
    # ========================================================================
    # ¿Qué es? Clustering jerárquico que construye un árbol de clusters
    # ¿Cómo funciona? Empieza con cada punto como cluster y los va fusionando
    # ¿Ventajas? No necesita especificar k inicialmente, crea jerarquía
    # ¿Linkage? Método para calcular distancia entre clusters (complete=máxima)
    
    # TAREA 5.4: Aplicar Agglomerative Clustering
    
    # TODO: Crea AgglomerativeClustering con n_clusters=2 y linkage='complete'
    agglo_umap = ___
    
    # TODO: Ajusta y predice clusters
    y_umap_agglo = ___
    
    # TODO: Calcula métricas (ARI y Silhouette)
    ari_agglo = ___
    sil_agglo = ___
    print(f'Adjusted Rand Index (Agglomerative): {ari_agglo:.3f}')
    print(f'Silhouette Score (Agglomerative): {sil_agglo:.3f}')
    
    # TODO: Visualiza los clusters
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(___, ___, c=___, cmap='tab10', alpha=0.8)
    plt.title('Agglomerative Clusters en UMAP')
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.legend(*scatter.legend_elements(), title='Clusters')
    plt.show()
    
    # ========================================================================
    # ALGORITMO 3: DBSCAN (Density-Based Spatial Clustering)
    # ========================================================================
    # ¿Qué es? Clustering basado en densidad de puntos
    # ¿Cómo funciona? Agrupa puntos densos y marca outliers como ruido
    # ¿Ventajas? Descubre clusters de forma arbitraria, detecta outliers
    # ¿Parámetros? eps=radio de vecindad, min_samples=mínimo de puntos
    
    # TAREA 5.5: Aplicar DBSCAN
    
    # TODO: Crea DBSCAN con eps=3 y min_samples=5
    dbscan_umap = ___
    
    # TODO: Ajusta y predice clusters
    y_umap_dbscan = ___
    
    # TODO: Calcula métricas
    ari_dbscan = ___
    sil_dbscan = ___
    print(f'Adjusted Rand Index (DBSCAN): {ari_dbscan:.3f}')
    print(f'Silhouette Score (DBSCAN): {sil_dbscan:.3f}')
    
    # TODO: Visualiza los clusters
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(___, ___, c=___, cmap='tab10', alpha=0.8)
    plt.title('DBSCAN Clusters en UMAP')
    plt.xlabel('UMAP1')
    plt.ylabel('UMAP2')
    plt.legend(*scatter.legend_elements(), title='Clusters')
    plt.show()
    
    print('\n✅ Clustering completado. Compara las métricas para elegir el mejor algoritmo.')
else:
    print('⚠️ Instala UMAP para continuar con el clustering')

# %% [markdown]
# ---
# ## Parte 6: Análisis Comparativo de Algoritmos
#
# ### 📝 Instrucciones:
#
# Compara el rendimiento de los tres algoritmos de clustering.

# %%
if UMAP_AVAILABLE:
    # TAREA 6.1: Crear tabla comparativa
    
    print("="*80)
    print("COMPARACIÓN DE ALGORITMOS DE CLUSTERING")
    print("="*80)
    
    # TODO: Crea un diccionario con los resultados de cada algoritmo
    # Estructura: {'NombreAlgo': {'ARI': valor, 'Silhouette': valor}}
    clustering_results = {
        'k-Means': {'ARI': ___, 'Silhouette': ___},
        'Agglomerative': {'ARI': ___, 'Silhouette': ___},
        'DBSCAN': {'ARI': ___, 'Silhouette': ___}
    }
    
    # TODO: Imprime una tabla formateada comparando las métricas
    print(f"\n{'Algoritmo':<20} {'ARI':<10} {'Silhouette':<10}")
    print("-" * 80)
    
    for algo, metrics in clustering_results.items():
        print(f"{algo:<20} {metrics['ARI']:.3f}      {metrics['Silhouette']:.3f}")
    
    print("\n" + "="*80)
    print("💡 INTERPRETACIÓN:")
    print("-" * 80)
    print("• ARI > 0.4: Buena concordancia con clases reales")
    print("• Silhouette > 0.5: Clusters bien definidos y separados")
    print("="*80)
    
    # PREGUNTA PARA REFLEXIONAR:
    # ¿Qué algoritmo tiene mejor ARI? ¿Y mejor Silhouette?
    # ¿Son siempre iguales? ¿Por qué podría haber diferencias?

# %% [markdown]
# ---
# ## Parte 7: Análisis de Correspondencia entre Clusters y Clases Reales
#
# ### 📝 Instrucciones:
#
# Analiza cómo los clusters se corresponden con las clases reales de enfermedad.

# %%
if UMAP_AVAILABLE:
    # TAREA 7.1: Crear matriz de confusión
    # ¿Qué es? Tabla que compara predicciones (clusters) vs realidad (clases)
    
    print("="*80)
    print("ANÁLISIS: CLASES REALES vs CLUSTERS K-MEANS")
    print("="*80)
    
    # TODO: Crea la matriz de confusión comparando y_heart con y_umap_kmeans
    cm = ___
    
    print("\n📊 Matriz de Confusión:")
    print("-" * 80)
    print(f"{'':20} Cluster 0   Cluster 1")
    print("-" * 80)
    print(f"Sin enfermedad:      {cm[0,0]:>5}       {cm[0,1]:>5}")
    print(f"Con enfermedad:      {cm[1,0]:>5}       {cm[1,1]:>5}")
    print("-" * 80)
    
    # TAREA 7.2: Calcular estadísticas por cluster
    
    print("\n📊 PERFIL DE CADA CLUSTER:")
    print("-" * 80)
    
    for cluster in range(2):
        # TODO: Cuenta cuántos pacientes hay en este cluster
        # Pista: usa np.sum() con y_umap_kmeans == cluster
        n_total = ___
        
        # TODO: Cuenta cuántos están sanos (y_heart==0) en este cluster
        # Pista: usa np.sum() con dos condiciones: cluster correcto Y y_heart==0
        n_healthy = ___
        
        # TODO: Cuenta cuántos están enfermos (y_heart==1) en este cluster
        n_diseased = ___
        
        print(f"\nCluster {cluster}:")
        print(f"  Total: {n_total} pacientes")
        print(f"  Sin enfermedad: {n_healthy} ({n_healthy/n_total*100:.1f}%)")
        print(f"  Con enfermedad: {n_diseased} ({n_diseased/n_total*100:.1f}%)")
        
        # TODO: Determina si es cluster de alto o bajo riesgo
        if n_diseased > n_healthy:
            perfil = "🔴 ALTO RIESGO"
        else:
            perfil = "🟢 BAJO RIESGO"
        print(f"  Perfil: {perfil}")
    
    print("="*80)
    
    # PREGUNTA PARA REFLEXIONAR:
    # ¿Los clusters separan bien a los pacientes sanos de los enfermos?
    # ¿Qué porcentaje de precisión tenemos en cada cluster?

# %% [markdown]
# ---
# ## Parte 8: Visualización Comparativa
#
# ### 📝 Instrucciones:
#
# Crea visualizaciones lado a lado para comparar clases reales vs clusters.

# %%
if UMAP_AVAILABLE:
    # TAREA 8.1: Crear figura con 2 subplots
    # ¿Por qué subplots? Para comparar visualmente en la misma escala
    
    # TODO: Crea una figura con 1 fila y 2 columnas de 16x6 pulgadas
    fig, axes = plt.subplots(___, ___, figsize=(___, ___))
    
    # SUBPLOT 1: Clases reales
    # TODO: Crea scatter plot en axes[0] con colores según y_heart
    scatter1 = axes[0].scatter(___, ___, c=___, cmap='RdYlGn_r', alpha=0.6, s=50)
    axes[0].set_title('Clases Reales', fontsize=14, fontweight='bold')
    axes[0].set_xlabel('UMAP1')
    axes[0].set_ylabel('UMAP2')
    axes[0].legend(*scatter1.legend_elements(), title='Enfermedad')
    
    # SUBPLOT 2: Clusters predichos
    # TODO: Crea scatter plot en axes[1] con colores según y_umap_kmeans
    scatter2 = axes[1].scatter(___, ___, c=___, cmap='viridis', alpha=0.6, s=50)
    axes[1].set_title('Clusters k-Means', fontsize=14, fontweight='bold')
    axes[1].set_xlabel('UMAP1')
    axes[1].set_ylabel('UMAP2')
    axes[1].legend(*scatter2.legend_elements(), title='Cluster')
    
    plt.tight_layout()
    plt.show()
    
    print("✅ Compara visualmente: ¿Los clusters capturan bien las clases reales?")

# %% [markdown]
# ---
# ## Parte 9: Análisis de Características Originales por Cluster
#
# ### 📝 Instrucciones:
#
# Identifica qué características médicas diferencian a cada cluster.

# %%
if UMAP_AVAILABLE:
    # TAREA 9.1: Preparar datos para análisis
    
    # TODO: Obtén los nombres de las características (todas menos 'HeartDisease')
    feature_names = df.drop('HeartDisease', axis=1).columns.tolist()
    
    # TODO: Crea un DataFrame con los datos escalados y nombres de columnas
    df_clustered = pd.DataFrame(___, columns=___)
    
    # TODO: Añade columna 'cluster' con las etiquetas de k-Means
    df_clustered['cluster'] = ___
    
    # TAREA 9.2: Calcular medias por cluster
    # ¿Por qué? Para ver qué valores son típicos de cada grupo
    
    # TODO: Agrupa por 'cluster' y calcula la media de cada característica
    cluster_means = ___
    
    print("="*80)
    print("CARACTERÍSTICAS PROMEDIO POR CLUSTER")
    print("="*80)
    print(cluster_means)
    
    # TAREA 9.3: Visualizar con heatmap
    # ¿Por qué heatmap? Permite ver patrones de muchas características a la vez
    
    # TODO: Crea figura de 14x8
    plt.figure(figsize=(___, ___))
    
    # TODO: Crea heatmap con seaborn:
    # - Transpón cluster_means con .T para tener features en filas
    # - annot=True para mostrar valores
    # - cmap='RdYlGn' para mapa de colores
    # - fmt=".2f" para formato de 2 decimales
    # - center=0 para centrar colores en 0
    sns.heatmap(___, annot=___, cmap=___, fmt=___, center=___)
    
    plt.title('Media de Características por Cluster', fontsize=14, fontweight='bold')
    plt.xlabel('Cluster')
    plt.ylabel('Características')
    plt.tight_layout()
    plt.show()
    
    # TAREA 9.4: Identificar características más discriminativas
    # ¿Qué buscamos? Características con mayor diferencia entre clusters
    
    print("\n" + "="*80)
    print("TOP 5 CARACTERÍSTICAS MÁS DISCRIMINATIVAS")
    print("="*80)
    
    # TODO: Calcula diferencia absoluta entre clusters y ordena descendente
    # Pista: abs(cluster_means.loc[0] - cluster_means.loc[1]).sort_values(ascending=False)
    diff_means = ___
    
    # TODO: Muestra las top 5 características
    print("\nCaracterísticas que más diferencian los clusters:")
    for i, (feature, diff) in enumerate(diff_means.head(5).items(), 1):
        print(f"{i}. {feature}: diferencia = {diff:.3f}")
    
    print("\n💡 Estas características son las más importantes para distinguir")
    print("   pacientes de alto vs bajo riesgo.")

# %% [markdown]
# ---
# ## 🎓 Preguntas de Reflexión Final
#
# Responde estas preguntas para consolidar tu aprendizaje:
#
# ### Sobre Reducción de Dimensionalidad:
#
# 1. **¿Cuál técnica captura más varianza en 2D: PCA, t-SNE o UMAP?**
#    - Revisa la varianza explicada de PCA
#    - Observa visualmente qué técnica separa mejor las clases
#
# 2. **¿Por qué PCA captura menos varianza que UMAP en este caso?**
#    - Piensa en relaciones lineales vs no lineales
#
# 3. **¿Cuándo usarías PCA vs UMAP en la práctica?**
#    - Considera velocidad, interpretabilidad y tipo de datos
#
# ### Sobre Clustering:
#
# 4. **¿Qué algoritmo de clustering funcionó mejor según las métricas?**
#    - Compara ARI y Silhouette de los 3 algoritmos
#
# 5. **¿Los clusters identifican correctamente pacientes con enfermedad?**
#    - Revisa los porcentajes de la matriz de confusión
#
# 6. **¿Qué características médicas son más importantes?**
#    - Mira el top 5 de características discriminativas
#
# ### Aplicación Clínica:
#
# 7. **¿Se podría usar este modelo para screening de pacientes?**
#    - Considera precisión, falsos positivos/negativos
#
# 8. **¿Qué mejoras propondrías?**
#    - Piensa en más datos, mejores features, otros algoritmos
#
# ---
#
# ## 🎯 Resumen de Conceptos Clave Aprendidos
#
# ✅ **Reducción de Dimensionalidad**:
# - PCA: rápido, lineal, interpretable
# - t-SNE: no lineal, bueno para visualización
# - UMAP: mejor balance estructura local/global
#
# ✅ **Clustering**:
# - k-Means: rápido, requiere especificar k
# - Agglomerative: jerárquico, crea dendrogramas
# - DBSCAN: basado en densidad, detecta outliers
#
# ✅ **Evaluación**:
# - ARI: concordancia con etiquetas reales
# - Silhouette: calidad de separación de clusters
#
# ✅ **Aplicación**:
# - Identificación de perfiles de riesgo
# - Interpretación clínica de clusters
# - Características discriminativas
#
# ---
#
# ## 📚 Recursos Adicionales
#
# - [Documentación PCA - Scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.PCA.html)
# - [Documentación t-SNE - Scikit-learn](https://scikit-learn.org/stable/modules/generated/sklearn.manifold.TSNE.html)
# - [Documentación UMAP](https://umap-learn.readthedocs.io/)
# - [Clustering - Scikit-learn](https://scikit-learn.org/stable/modules/clustering.html)
#
# ---
#
# **¡Felicitaciones por completar el ejercicio! 🎉**
#
# Has aprendido a aplicar técnicas avanzadas de ML no supervisado para análisis de datos médicos.
